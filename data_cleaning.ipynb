# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

df=pd.read_csv("IBRD_ loan_dataset_copy.csv")
df.head()
# Out:
#          End of Period Loan Number                   Region Country Code  \
# 0  2018-09-30T00:00:00   IBRD00010  EUROPE AND CENTRAL ASIA           FR
# 1  2018-09-30T00:00:00   IBRD00020  EUROPE AND CENTRAL ASIA           NL
# 2  2018-09-30T00:00:00   IBRD00021  EUROPE AND CENTRAL ASIA           NL
# 3  2018-09-30T00:00:00   IBRD00030  EUROPE AND CENTRAL ASIA           DK
# 4  2018-09-30T00:00:00   IBRD00040  EUROPE AND CENTRAL ASIA           LU
#
#        Country         Borrower Guarantor Country Code Guarantor Loan Type  \
# 0       France  CREDIT NATIONAL                     FR    France  NON POOL
# 1  Netherlands              NaN                    NaN       NaN  NON POOL
# 2  Netherlands              NaN                    NaN       NaN  NON POOL
# 3      Denmark              NaN                    NaN       NaN  NON POOL
# 4   Luxembourg              NaN                    NaN       NaN  NON POOL
#
#     Loan Status           ...            Repaid 3rd Party  Due 3rd Party  \
# ...

# %%
#drop unnecessary columns

to_drop=['Currency of Commitment','Due 3rd Party','Loans Held','Agreement Signing Date','Board Approval Date','Effective Date (Most Recent)','Closed Date (Most Recent)','Last Disbursement Date','Undisbursed Amount','Disbursed Amount','Country Code','Guarantor Country Code','Exchange Adjustment','Borrower\'s Obligation','Due to IBRD','Repaid 3rd Party','Sold 3rd Party']
df.drop(to_drop, inplace=True, axis=1)

# %%
df
# Out:
#             End of Period Loan Number                        Region  \
# 0     2018-09-30T00:00:00   IBRD00010       EUROPE AND CENTRAL ASIA
# 1     2018-09-30T00:00:00   IBRD00020       EUROPE AND CENTRAL ASIA
# 2     2018-09-30T00:00:00   IBRD00021       EUROPE AND CENTRAL ASIA
# 3     2018-09-30T00:00:00   IBRD00030       EUROPE AND CENTRAL ASIA
# 4     2018-09-30T00:00:00   IBRD00040       EUROPE AND CENTRAL ASIA
# 5     2018-09-30T00:00:00   IBRD00050   LATIN AMERICA AND CARIBBEAN
# 6     2018-09-30T00:00:00   IBRD00060   LATIN AMERICA AND CARIBBEAN
# 7     2018-09-30T00:00:00   IBRD00070       EUROPE AND CENTRAL ASIA
# 8     2018-09-30T00:00:00   IBRD00071       EUROPE AND CENTRAL ASIA
# 9     2018-09-30T00:00:00   IBRD00080       EUROPE AND CENTRAL ASIA
# 10    2018-09-30T00:00:00   IBRD00090       EUROPE AND CENTRAL ASIA
# 11    2018-09-30T00:00:00   IBRD00100       EUROPE AND CENTRAL ASIA
# 12    2018-09-30T00:00:00   IBRD00101       EUROPE AND CENTRAL ASIA
# ...

# %%
# to replace all the 0s in numerical columns with NaNs

df.replace(0,np.nan,inplace=True)

# %%
df.head()
# Out:
#          End of Period Loan Number                   Region      Country  \
# 0  2018-09-30T00:00:00   IBRD00010  EUROPE AND CENTRAL ASIA       France
# 1  2018-09-30T00:00:00   IBRD00020  EUROPE AND CENTRAL ASIA  Netherlands
# 2  2018-09-30T00:00:00   IBRD00021  EUROPE AND CENTRAL ASIA  Netherlands
# 3  2018-09-30T00:00:00   IBRD00030  EUROPE AND CENTRAL ASIA      Denmark
# 4  2018-09-30T00:00:00   IBRD00040  EUROPE AND CENTRAL ASIA   Luxembourg
#
#           Borrower Guarantor Loan Type   Loan Status  Interest Rate  \
# 0  CREDIT NATIONAL    France  NON POOL  Fully Repaid           4.25
# 1              NaN       NaN  NON POOL  Fully Repaid           4.25
# 2              NaN       NaN  NON POOL  Fully Repaid           4.25
# 3              NaN       NaN  NON POOL  Fully Repaid           4.25
# 4              NaN       NaN  NON POOL  Fully Repaid           4.25
#
#   Project ID    Project Name  Original Principal Amount  Cancelled Amount  \
# ...

# %%
#interpolation

Cancelled_Amount_first = df['Cancelled Amount'].index[4]
Cancelled_Amount_last = df['Cancelled Amount'].index[16]
df.loc[Cancelled_Amount_first:Cancelled_Amount_last, 'Cancelled Amount'] = df.loc[Cancelled_Amount_first:Cancelled_Amount_last, 'Cancelled Amount'].interpolate()
print(df)
# Out:
#             End of Period Loan Number                        Region  \
# 0     2018-09-30T00:00:00   IBRD00010       EUROPE AND CENTRAL ASIA
# 1     2018-09-30T00:00:00   IBRD00020       EUROPE AND CENTRAL ASIA
# 2     2018-09-30T00:00:00   IBRD00021       EUROPE AND CENTRAL ASIA
# 3     2018-09-30T00:00:00   IBRD00030       EUROPE AND CENTRAL ASIA
# 4     2018-09-30T00:00:00   IBRD00040       EUROPE AND CENTRAL ASIA
# 5     2018-09-30T00:00:00   IBRD00050   LATIN AMERICA AND CARIBBEAN
# 6     2018-09-30T00:00:00   IBRD00060   LATIN AMERICA AND CARIBBEAN
# 7     2018-09-30T00:00:00   IBRD00070       EUROPE AND CENTRAL ASIA
# 8     2018-09-30T00:00:00   IBRD00071       EUROPE AND CENTRAL ASIA
# 9     2018-09-30T00:00:00   IBRD00080       EUROPE AND CENTRAL ASIA
# 10    2018-09-30T00:00:00   IBRD00090       EUROPE AND CENTRAL ASIA
# 11    2018-09-30T00:00:00   IBRD00100       EUROPE AND CENTRAL ASIA
# 12    2018-09-30T00:00:00   IBRD00101       EUROPE AND CENTRAL ASIA
# ...

# %%
#fill all the NaNs with the previous values in categorical columns 

df=df.fillna(method='ffill')
df
# Out:
#             End of Period Loan Number                        Region  \
# 0     2018-09-30T00:00:00   IBRD00010       EUROPE AND CENTRAL ASIA
# 1     2018-09-30T00:00:00   IBRD00020       EUROPE AND CENTRAL ASIA
# 2     2018-09-30T00:00:00   IBRD00021       EUROPE AND CENTRAL ASIA
# 3     2018-09-30T00:00:00   IBRD00030       EUROPE AND CENTRAL ASIA
# 4     2018-09-30T00:00:00   IBRD00040       EUROPE AND CENTRAL ASIA
# 5     2018-09-30T00:00:00   IBRD00050   LATIN AMERICA AND CARIBBEAN
# 6     2018-09-30T00:00:00   IBRD00060   LATIN AMERICA AND CARIBBEAN
# 7     2018-09-30T00:00:00   IBRD00070       EUROPE AND CENTRAL ASIA
# 8     2018-09-30T00:00:00   IBRD00071       EUROPE AND CENTRAL ASIA
# 9     2018-09-30T00:00:00   IBRD00080       EUROPE AND CENTRAL ASIA
# 10    2018-09-30T00:00:00   IBRD00090       EUROPE AND CENTRAL ASIA
# 11    2018-09-30T00:00:00   IBRD00100       EUROPE AND CENTRAL ASIA
# 12    2018-09-30T00:00:00   IBRD00101       EUROPE AND CENTRAL ASIA
# ...

# %%
#REPLACING ALL THE NaNs of NUMERICAL COLUMNS WITH THEIR RESPECTIVE MEANS

# %%
#Interest Rate

int_mean=df['Interest Rate'].mean(axis=0)
interest_mean=round(int_mean,3)
print("Mean:",interest_mean)

int_std=df['Interest Rate'].std(axis=0)
interest_std= round(int_std,3)
print("Standard Deviation:",interest_std)

df['Interest Rate'].replace(np.nan,interest_mean,inplace=True)

print(df['Interest Rate'])
# Out:
# Mean: 5.268
# Standard Deviation: 2.625
# 0       4.25
# 1       4.25
# 2       4.25
# 3       4.25
# 4       4.25
# 5       4.50
# 6       3.75
# 7       3.56
# 8       3.56
# 9       3.56
# 10      3.56
# 11      3.56
# 12      3.56
# 13      4.50
# 14      4.25
# 15      4.50
# 16      4.50
# 17      4.25
# 18      4.00
# 19      4.00
# 20      4.00
# 21      3.50
# 22      3.50
# 23      3.00
# 24      3.00
# 25      4.25
# 26      4.00
# 27      4.50
# 28      4.25
# 29      3.75
#         ...
# 8680    5.56
# 8681    5.58
# 8682    5.72
# 8683    5.52
# 8684    4.25
# 8685    5.68
# 8686    3.96
# 8687    3.96
# 8688    2.25
# 8689    6.00
# 8690    6.50
# 8691    7.25
# 8692    8.50
# 8693    8.20
# 8694    8.00
# 8695    8.00
# 8696    7.45
# 8697    7.45
# 8698    7.50
# 8699    7.50
# 8700    7.35
# 8701    7.35
# 8702    7.35
# 8703    7.90
# 8704    7.95
# 8705    7.95
# 8706    7.95
# 8707    8.25
# 8708    8.25
# 8709    9.25
# ...

# %%
df['Interest Rate'].hist(bins=10)

# %%
# Normalization of Interest Rate

int_norm=(df['Interest Rate']-interest_mean)/interest_std
df['Interest Rate']=int_norm
print(df['Interest Rate'])
# Out:
# 0      -0.387810
# 1      -0.387810
# 2      -0.387810
# 3      -0.387810
# 4      -0.387810
# 5      -0.292571
# 6      -0.578286
# 7      -0.650667
# 8      -0.650667
# 9      -0.650667
# 10     -0.650667
# 11     -0.650667
# 12     -0.650667
# 13     -0.292571
# 14     -0.387810
# 15     -0.292571
# 16     -0.292571
# 17     -0.387810
# 18     -0.483048
# 19     -0.483048
# 20     -0.483048
# 21     -0.673524
# 22     -0.673524
# 23     -0.864000
# 24     -0.864000
# 25     -0.387810
# 26     -0.483048
# 27     -0.292571
# 28     -0.387810
# 29     -0.578286
#           ...
# 8680    0.111238
# 8681    0.118857
# 8682    0.172190
# 8683    0.096000
# 8684   -0.387810
# 8685    0.156952
# 8686   -0.498286
# 8687   -0.498286
# 8688   -1.149714
# 8689    0.278857
# 8690    0.469333
# 8691    0.755048
# 8692    1.231238
# 8693    1.116952
# 8694    1.040762
# 8695    1.040762
# 8696    0.831238
# 8697    0.831238
# 8698    0.850286
# 8699    0.850286
# 8700    0.793143
# ...

# %%
print(round(int_norm.mean()))
print(round(int_norm.std()))
# Out:
# 0
# 1

# %%
int_norm.hist(bins=10)

# %%
#Original Principal Amount

pri_mean=df['Original Principal Amount'].mean(axis=0)
principal_mean=round(pri_mean)
print( "Mean:",principal_mean)

pri_std=df['Original Principal Amount'].std(axis=0)
principal_std= round(pri_std)
print("Standard deviation:",principal_std)

df['Original Principal Amount'].replace(np.nan,principal_mean,inplace=True)

print(df['Original Principal Amount'])
# Out:
# Mean: 85349546
# Standard deviation: 155181693
# 0       2.500000e+08
# 1       1.910442e+08
# 2       3.955788e+06
# 3       4.000000e+07
# 4       1.200000e+07
# 5       1.350000e+07
# 6       2.500000e+06
# 7       2.000000e+06
# 8       2.000000e+06
# 9       2.000000e+06
# 10      2.000000e+06
# 11      2.000000e+06
# 12      2.000000e+06
# 13      7.500000e+07
# 14      1.500000e+07
# 15      2.410000e+07
# 16      1.000000e+07
# 17      1.600000e+07
# 18      1.500000e+07
# 19      1.250000e+07
# 20      3.400000e+07
# 21      5.000000e+06
# 22      1.000000e+07
# 23      2.700000e+06
# 24      2.300000e+06
# 25      1.254500e+07
# 26      1.850000e+07
# 27      2.600000e+07
# 28      1.500000e+07
# 29      1.280000e+07
#             ...
# 8680    5.000000e+06
# 8681    4.000000e+06
# 8682    3.800000e+06
# 8683    3.000000e+06
# 8684    5.011415e+06
# 8685    5.000000e+06
# 8686    5.000000e+07
# 8687    1.961909e+08
# 8688    1.961909e+08
# 8689    1.700000e+06
# ...

# %%
df['Original Principal Amount'].hist(bins=10)

# %%
# Normalization of Original Principal Amount

pri_norm=(df['Original Principal Amount']-principal_mean)/principal_std
df['Original Principal Amount']=pri_norm
print(df['Original Principal Amount'])
# Out:
# 0       1.061017
# 1       0.681103
# 2      -0.524506
# 3      -0.292235
# 4      -0.472669
# 5      -0.463003
# 6      -0.533887
# 7      -0.537109
# 8      -0.537109
# 9      -0.537109
# 10     -0.537109
# 11     -0.537109
# 12     -0.537109
# 13     -0.066693
# 14     -0.453337
# 15     -0.394696
# 16     -0.485557
# 17     -0.446893
# 18     -0.453337
# 19     -0.469447
# 20     -0.330900
# 21     -0.517777
# 22     -0.485557
# 23     -0.532599
# 24     -0.535176
# 25     -0.469157
# 26     -0.430782
# 27     -0.382452
# 28     -0.453337
# 29     -0.467514
#           ...
# 8680   -0.517777
# 8681   -0.524221
# 8682   -0.525510
# 8683   -0.530665
# 8684   -0.517704
# 8685   -0.517777
# 8686   -0.227795
# 8687    0.714269
# 8688    0.714269
# 8689   -0.539043
# 8690   -0.544520
# 8691   -0.546131
# 8692   -0.535176
# 8693   -0.533887
# 8694   -0.479113
# 8695   -0.540331
# 8696   -0.545115
# 8697   -0.541992
# 8698   -0.485557
# 8699   -0.518422
# 8700   -0.493290
# ...

# %%
print(round(pri_norm.mean()))
print(round(pri_norm.std()))
# Out:
# 0
# 1

# %%
pri_norm.hist(bins=10)

# %%
#Cancelled Amount

can_mean=df['Cancelled Amount'].mean(axis=0)
cancelled_mean=round(can_mean)
print( "Mean:",cancelled_mean)

can_std=df['Cancelled Amount'].std(axis=0)
cancelled_std= round(can_std)
print("Standard deviation:",cancelled_std)

df['Cancelled Amount'].replace(np.nan,cancelled_mean,inplace=True)

print(df['Cancelled Amount'])
# Out:
# Mean: 26423746
# Standard deviation: 97616594
# 0       2.642375e+07
# 1       2.642375e+07
# 2       2.642375e+07
# 3       2.642375e+07
# 4       2.380170e+05
# 5       1.051516e+06
# 6       1.865014e+06
# 7       2.678513e+06
# 8       3.492011e+06
# 9       4.305510e+06
# 10      5.119008e+06
# 11      5.932507e+06
# 12      6.746006e+06
# 13      7.559504e+06
# 14      8.373003e+06
# 15      9.186501e+06
# 16      1.000000e+07
# 17      1.000000e+07
# 18      7.548015e+06
# 19      7.548015e+06
# 20      1.200000e+06
# 21      7.455916e+04
# 22      2.796187e+06
# 23      2.796187e+06
# 24      1.978689e+05
# 25      1.978689e+05
# 26      1.779500e+06
# 27      1.779500e+06
# 28      1.779500e+06
# 29      6.506054e+06
#             ...
# 8680    1.300000e+06
# 8681    1.300000e+06
# 8682    1.300000e+06
# 8683    1.300000e+06
# 8684    1.300000e+06
# 8685    4.000000e+06
# 8686    4.000000e+06
# 8687    4.000000e+06
# 8688    4.000000e+06
# 8689    1.700000e+06
# ...

# %%
df['Cancelled Amount'].hist(bins=10)

# %%
# Normalization of Cancelled Amount

can_norm=(df['Cancelled Amount']-cancelled_mean)/cancelled_std
df['Cancelled Amount']=can_norm
print(df['Cancelled Amount'])
# Out:
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4      -0.268251
# 5      -0.259917
# 6      -0.251584
# 7      -0.243250
# 8      -0.234916
# 9      -0.226583
# 10     -0.218249
# 11     -0.209916
# 12     -0.201582
# 13     -0.193248
# 14     -0.184915
# 15     -0.176581
# 16     -0.168247
# 17     -0.168247
# 18     -0.193366
# 19     -0.193366
# 20     -0.258396
# 21     -0.269925
# 22     -0.242044
# 23     -0.242044
# 24     -0.268662
# 25     -0.268662
# 26     -0.252460
# 27     -0.252460
# 28     -0.252460
# 29     -0.204040
#           ...
# 8680   -0.257372
# 8681   -0.257372
# 8682   -0.257372
# 8683   -0.257372
# 8684   -0.257372
# 8685   -0.229712
# 8686   -0.229712
# 8687   -0.229712
# 8688   -0.229712
# 8689   -0.253274
# 8690   -0.261982
# 8691   -0.269584
# 8692   -0.253018
# 8693   -0.270668
# 8694   -0.270668
# 8695   -0.270160
# 8696   -0.270160
# 8697   -0.262022
# 8698   -0.270381
# 8699   -0.223617
# 8700   -0.264353
# ...

# %%
print(round(can_norm.mean()))
print(round(can_norm.std()))
# Out:
# 0
# 1

# %%
can_norm.hist(bins=10)

# %%
#Repaid to IBRD

repay_mean=df['Repaid to IBRD'].mean(axis=0)
ibrd_mean=round(repay_mean)
print( "Mean:",ibrd_mean)

repay_std=df['Repaid to IBRD'].std(axis=0)
ibrd_std= round(repay_std)
print("Standard deviation:",ibrd_std)

df['Repaid to IBRD'].replace(np.nan,ibrd_mean,inplace=True)

print(df['Repaid to IBRD'])
# Out:
# Mean: 47039917
# Standard deviation: 92626771
# 0       3.800000e+04
# 1       1.033722e+08
# 2       1.033722e+08
# 3       1.777100e+07
# 4       1.619983e+06
# 5       1.216700e+07
# 6       7.550000e+05
# 7       7.550000e+05
# 8       7.550000e+05
# 9       7.550000e+05
# 10      7.550000e+05
# 11      7.550000e+05
# 12      7.550000e+05
# 13      7.097159e+07
# 14      1.500000e+07
# 15      2.013170e+07
# 16      2.013170e+07
# 17      2.013170e+07
# 18      1.025089e+06
# 19      6.747990e+06
# 20      1.505637e+07
# 21      2.925441e+06
# 22      2.263000e+06
# 23      2.700000e+06
# 24      2.102131e+06
# 25      1.154500e+07
# 26      1.085150e+07
# 27      2.197400e+07
# 28      1.500000e+07
# 29      6.293946e+06
#             ...
# 8680    5.000000e+06
# 8681    4.000000e+06
# 8682    3.800000e+06
# 8683    3.000000e+06
# 8684    4.186142e+06
# 8685    1.000000e+06
# 8686    4.998978e+07
# 8687    4.998978e+07
# 8688    1.961909e+08
# 8689    1.961909e+08
# ...

# %%
df['Repaid to IBRD'].hist(bins=10)

# %%
# Normalization of Repaid to IBRD

ibrd_norm=(df['Repaid to IBRD']-ibrd_mean)/ibrd_std
df['Repaid to IBRD']=ibrd_norm
print(df['Repaid to IBRD'])
# Out:
# 0      -0.507433
# 1       0.608164
# 2       0.608164
# 3      -0.315988
# 4      -0.490354
# 5      -0.376489
# 6      -0.499693
# 7      -0.499693
# 8      -0.499693
# 9      -0.499693
# 10     -0.499693
# 11     -0.499693
# 12     -0.499693
# 13      0.258367
# 14     -0.345903
# 15     -0.290502
# 16     -0.290502
# 17     -0.290502
# 18     -0.496777
# 19     -0.434992
# 20     -0.345295
# 21     -0.476261
# 22     -0.483412
# 23     -0.478694
# 24     -0.485149
# 25     -0.383204
# 26     -0.390691
# 27     -0.270612
# 28     -0.345903
# 29     -0.439894
#           ...
# 8680   -0.453864
# 8681   -0.464660
# 8682   -0.466819
# 8683   -0.475456
# 8684   -0.462650
# 8685   -0.497048
# 8686    0.031847
# 8687    0.031847
# 8688    1.610237
# 8689    1.610237
# 8690    1.610237
# 8691   -0.502531
# 8692   -0.501636
# 8693   -0.480876
# 8694   -0.389087
# 8695   -0.492208
# 8696   -0.499663
# 8697   -0.503566
# 8698   -0.400208
# 8699   -0.504551
# 8700   -0.419516
# ...

# %%
print(round(ibrd_norm.mean()))
print(round(ibrd_norm.std()))
# Out:
# 0
# 1

# %%
ibrd_norm.hist(bins=10)

# %%
#Cleaned Data

df
# Out:
#             End of Period Loan Number                        Region  \
# 0     2018-09-30T00:00:00   IBRD00010       EUROPE AND CENTRAL ASIA
# 1     2018-09-30T00:00:00   IBRD00020       EUROPE AND CENTRAL ASIA
# 2     2018-09-30T00:00:00   IBRD00021       EUROPE AND CENTRAL ASIA
# 3     2018-09-30T00:00:00   IBRD00030       EUROPE AND CENTRAL ASIA
# 4     2018-09-30T00:00:00   IBRD00040       EUROPE AND CENTRAL ASIA
# 5     2018-09-30T00:00:00   IBRD00050   LATIN AMERICA AND CARIBBEAN
# 6     2018-09-30T00:00:00   IBRD00060   LATIN AMERICA AND CARIBBEAN
# 7     2018-09-30T00:00:00   IBRD00070       EUROPE AND CENTRAL ASIA
# 8     2018-09-30T00:00:00   IBRD00071       EUROPE AND CENTRAL ASIA
# 9     2018-09-30T00:00:00   IBRD00080       EUROPE AND CENTRAL ASIA
# 10    2018-09-30T00:00:00   IBRD00090       EUROPE AND CENTRAL ASIA
# 11    2018-09-30T00:00:00   IBRD00100       EUROPE AND CENTRAL ASIA
# 12    2018-09-30T00:00:00   IBRD00101       EUROPE AND CENTRAL ASIA
# ...
